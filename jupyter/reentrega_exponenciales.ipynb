# %%
import pandas as pd
import numpy as np
import plotly as py
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns
import random
sns.set()

# %%
bff = pd.read_csv('experiments_results/reentrega/todos_bruteforce.csv', sep=";")
bff.t = bff.t.str[0:-2].astype(float)
bf = bff.groupby(["function","n"]).mean().reset_index()

# %%
mitmf = pd.read_csv('experiments_results/reentrega/todos_MITM.csv', sep=";")
mitmf.t = mitmf.t.str[0:-2].astype(float)
mitm = mitmf.groupby(["function","n"]).mean().reset_index()

# %%
f, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharey="col", sharex=True)
bf.groupby('function').plot(x="n", y="t", ax=axes[0][0], title="(a) Fuerza bruta, escala 1:1")
bf.groupby('function').plot(x="n", y="t", ax=axes[0][1], title="(b) Fuerza bruta, escala logarítmica", logy=True)

mitm.groupby('function').plot(x="n", y="t", ax=axes[1][0], title="(c) MitM, escala 1:1")
mitm.groupby('function').plot(x="n", y="t", ax=axes[1][1], title="(d) MitM, escala logarítmica", logy=True)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# function
# allItemsSize1Value1_nEqualsW    AxesSubplot(0.547727,0.11;0.352273x0.35)
# allItemsSize1_nEqualsW          AxesSubplot(0.547727,0.11;0.352273x0.35)
# fixedBkpSize                    AxesSubplot(0.547727,0.11;0.352273x0.35)
# nEqualBkpSize                   AxesSubplot(0.547727,0.11;0.352273x0.35)
# dtype: object
