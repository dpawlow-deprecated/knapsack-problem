# %%
import pandas as pd
import numpy as np
import plotly as py
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns
import random
sns.set()

# %%
dinamicaf = pd.read_csv('experiments_results/reentrega/dinamica.csv', sep=";")
dinamicaf.t = dinamicaf.t.str[0:-2].astype(float)
dinamica = dinamicaf.groupby(["function","n"]).mean().reset_index()

# %%
fig, ax = plt.subplots(figsize=(10,5))
dinamica.groupby('function').plot(x="n", y="t", ax=ax, title="Instancias de dinámica")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# function
# allItemsSize1Value1_nEqualsW    AxesSubplot(0.125,0.11;0.775x0.77)
# allItemsSize1_nEqualsW          AxesSubplot(0.125,0.11;0.775x0.77)
# fixedBkpSize                    AxesSubplot(0.125,0.11;0.775x0.77)
# nEqualBkpSize                   AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object
